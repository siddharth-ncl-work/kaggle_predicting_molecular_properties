# %% [markdown]
# <a href="https://colab.research.google.com/github/ss-ghule/kaggle_predicting_molecular_properties/blob/master/kaggle_combined_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import gc
gc.collect()
# Out:
# 552

# %%
train_v2=pd.read_csv('train_feat_eng_v2.csv')
train_orig=pd.read_csv('train_feat_eng.csv')

# %%
train_v2.head()
# Out:
#    atom_index_0  atom_index_1  ...  mulliken_atom_1  scalar_coupling_constant
# 0             1             0  ...        -0.535689                   84.8076
# 1             1             2  ...         0.133922                  -11.2570
# 2             1             3  ...         0.133923                  -11.2548
# 3             1             4  ...         0.133923                  -11.2543
# 4             2             0  ...        -0.535689                   84.8074
#
# [5 rows x 37 columns]

# %%
train_orig.head()
# Out:
#    pairs_enc  distance  bond_int  type_enc  scalar_coupling_constant
# 0          2  1.091953         1         0                   84.8076
# 1         11  1.783120         1         3                  -11.2570
# 2         11  1.783147         1         3                  -11.2548
# 3         11  1.783157         1         3                  -11.2543
# 4          2  1.091952         1         0                   84.8074

# %%
print(train_v2.shape)
print(train_orig.shape)
# Out:
# (4658147, 37)
# (4658147, 5)

# %%
train_v2['pairs_enc']=train_orig['pairs_enc']
train_v2['bond_int']=train_orig['bond_int']

# %%
train_v2.head()
# Out:
#    atom_index_0  atom_index_1  ...  pairs_enc  bond_int
# 0             1             0  ...          2         1
# 1             1             2  ...         11         1
# 2             1             3  ...         11         1
# 3             1             4  ...         11         1
# 4             2             0  ...          2         1
#
# [5 rows x 39 columns]

# %%
train_v2.columns
# Out:
# Index(['atom_index_0', 'atom_index_1', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1',
#        'z_1', 'distance', 'type_enc', 'atom_1_enc', 'atom_0_enc', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'r2', 'zpve',
#        'U0', 'U', 'H', 'G', 'Cv', 'freqs_min', 'freqs_max', 'freqs_mean',
#        'linear', 'mulliken_min', 'mulliken_max', 'mulliken_mean',
#        'mulliken_atom_0', 'mulliken_atom_1', 'scalar_coupling_constant',
#        'pairs_enc', 'bond_int'],
#       dtype='object')

# %%
train_v2=train_v2[['atom_index_0', 'atom_index_1', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1',
       'z_1', 'distance', 'type_enc', 'atom_1_enc', 'atom_0_enc', 'rc_A',
       'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'r2', 'zpve',
       'U0', 'U', 'H', 'G', 'Cv', 'freqs_min', 'freqs_max', 'freqs_mean',
       'linear', 'mulliken_min', 'mulliken_max', 'mulliken_mean',
       'mulliken_atom_0', 'mulliken_atom_1', 
       'pairs_enc', 'bond_int','scalar_coupling_constant']]

# %%
train_v2.head()
# Out:
#    atom_index_0  atom_index_1  ...  bond_int  scalar_coupling_constant
# 0             1             0  ...         1                   84.8076
# 1             1             2  ...         1                  -11.2570
# 2             1             3  ...         1                  -11.2548
# 3             1             4  ...         1                  -11.2543
# 4             2             0  ...         1                   84.8074
#
# [5 rows x 39 columns]

# %%
train_v2.to_csv('train_feat_eng_v2_with_bonds.csv',index=False)

# %% [markdown]
# # Test

# %%
test_v2=pd.read_csv('test_feat_eng_v2.csv')
test_orig=pd.read_csv('test_feat_eng.csv')

# %%
test_v2.head()
# Out:
#    atom_index_0  atom_index_1  ...  mulliken_atom_0  mulliken_atom_1
# 0             2             0  ...         0.207019        -0.207019
# 1             2             1  ...         0.207019        -0.207019
# 2             2             3  ...         0.207019         0.207019
# 3             3             0  ...         0.207019        -0.207019
# 4             3             1  ...         0.207019        -0.207019
#
# [5 rows x 37 columns]

# %%
test_orig.head()
# Out:
#    pairs_enc  distance  bond_int  total_charge        dp  type_enc
# 0          2  2.261178         0      0.057238 -0.211400         2
# 1          2  1.062099         1      0.057238 -0.099297         0
# 2         11  3.323277         0      0.240297 -0.006518         6
# 3          2  1.062099         1      0.057238 -0.099297         0
# 4          2  2.261178         0      0.057238 -0.211400         2

# %%
print(train_v2.shape)
print(train_orig.shape)
# Out:
# (4658147, 39)
# (4658147, 5)

# %%
test_v2['pairs_enc']=train_orig['pairs_enc']
test_v2['bond_int']=train_orig['bond_int']

# %%
train_v2.columns
# Out:
# Index(['atom_index_0', 'atom_index_1', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1',
#        'z_1', 'distance', 'type_enc', 'atom_1_enc', 'atom_0_enc', 'rc_A',
#        'rc_B', 'rc_C', 'mu', 'alpha', 'homo', 'lumo', 'gap', 'r2', 'zpve',
#        'U0', 'U', 'H', 'G', 'Cv', 'freqs_min', 'freqs_max', 'freqs_mean',
#        'linear', 'mulliken_min', 'mulliken_max', 'mulliken_mean',
#        'mulliken_atom_0', 'mulliken_atom_1', 'pairs_enc', 'bond_int',
#        'scalar_coupling_constant'],
#       dtype='object')

# %%
test_v2.columns
# Out:
# Index(['atom_index_0', 'atom_index_1', 'x_0', 'y_0', 'z_0', 'x_1', 'y_1',
#        'z_1', 'distance', 'type_enc', 'atom_0_enc', 'atom_1_enc',
#        'scalar_coupling_constant', 'rc_A', 'rc_B', 'rc_C', 'mu', 'alpha',
#        'homo', 'lumo', 'gap', 'r2', 'zpve', 'U0', 'U', 'H', 'G', 'Cv',
#        'freqs_min', 'freqs_max', 'freqs_mean', 'linear', 'mulliken_min',
#        'mulliken_max', 'mulliken_mean', 'mulliken_atom_0', 'mulliken_atom_1',
#        'pairs_enc', 'bond_int'],
#       dtype='object')

# %%
test_v2.to_csv('test_feat_eng_v2_with_bonds.csv',index=False)
